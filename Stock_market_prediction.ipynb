# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_24484\555797462.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data=pd.read_csv("NSE-TATAGLOBAL11.csv")
data
# Out:
#             Date    Open    High     Low    Last   Close  \
# 0     2018-10-08  208.00  222.25  206.85  216.00  215.15
# 1     2018-10-05  217.00  218.60  205.90  210.25  209.20
# 2     2018-10-04  223.50  227.80  216.15  217.25  218.20
# 3     2018-10-03  230.00  237.50  225.75  226.45  227.60
# 4     2018-10-01  234.55  234.60  221.05  230.30  230.90
# ...          ...     ...     ...     ...     ...     ...
# 1230  2013-10-14  160.85  161.45  157.70  159.30  159.45
# 1231  2013-10-11  161.15  163.45  159.00  159.80  160.05
# 1232  2013-10-10  156.00  160.80  155.85  160.30  160.15
# 1233  2013-10-09  155.70  158.20  154.15  155.30  155.55
# 1234  2013-10-08  157.00  157.80  155.20  155.80  155.80
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                4642146.0         10062.83
# 1                3519515.0          7407.06
# 2                1728786.0          3815.79
# 3                1708590.0          3960.27
# 4                1534749.0          3486.05
# ...

# %% [markdown]
# # Data Preprocessing

# %%
data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Last', 'Close', 'Total Trade Quantity',
#        'Turnover (Lacs)'],
#       dtype='object')

# %%
data.shape
# Out:
# (1235, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1235 entries, 0 to 1234
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  1235 non-null   object
#  1   Open                  1235 non-null   float64
#  2   High                  1235 non-null   float64
#  3   Low                   1235 non-null   float64
#  4   Last                  1235 non-null   float64
#  5   Close                 1235 non-null   float64
#  6   Total Trade Quantity  1235 non-null   float64
#  7   Turnover (Lacs)       1235 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 77.3+ KB

# %%
data.describe()
# Out:
#               Open         High          Low         Last        Close  \
# count  1235.000000  1235.000000  1235.000000  1235.000000  1235.000000
# mean    168.954858   171.429069   166.402308   168.736356   168.731053
# std      51.499145    52.436761    50.542919    51.587384    51.544928
# min     103.000000   104.600000   100.000000   102.600000   102.650000
# 25%     137.550000   138.925000   135.250000   137.175000   137.225000
# 50%     151.500000   153.250000   149.500000   151.200000   151.100000
# 75%     169.000000   172.325000   166.700000   169.100000   169.500000
# max     327.700000   328.750000   321.650000   325.950000   325.750000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          1.235000e+03      1235.000000
# mean           2.604151e+06      4843.166502
# std            2.277028e+06      5348.919832
# min            1.001800e+05       128.040000
# 25%            1.284482e+06      1801.035000
# 50%            1.964885e+06      3068.510000
# ...

# %%
data.isnull().sum()
# Out:
# Date                    0
# Open                    0
# High                    0
# Low                     0
# Last                    0
# Close                   0
# Total Trade Quantity    0
# Turnover (Lacs)         0
# dtype: int64

# %%
data.nunique()
# Out:
# Date                    1235
# Open                     799
# High                     863
# Low                      854
# Last                     865
# Close                    893
# Total Trade Quantity    1234
# Turnover (Lacs)         1231
# dtype: int64

# %% [markdown]
# # EDA

# %%
data['Open'].hist(bins=400)
plt.show()

# %%
data['High'].hist(bins=250)
plt.show()

# %%
data['Low'].hist(bins=550)
plt.show()

# %%
data['Last'].hist(bins=100)
plt.show()

# %%
data['Close'].hist(bins=300)
plt.show()

# %%
data['Total Trade Quantity'].hist(bins=20)
plt.show()

# %%
data['Turnover (Lacs)'].hist(bins=100)
plt.show()

# %%
#Distribution plot
plt.figure(figsize=(15,5))
sns.distplot(np.log1p(data['Open']), hist=False, color="b", kde_kws={"shade": True})
plt.xlabel("Open")
plt.ylabel("Frequency")
plt.title("Distribution of Open")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_24484\621124130.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log1p(data['Open']), hist=False, color="b", kde_kws={"shade": True})
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)

# %%
plt.figure(figsize=(15,5))
sns.distplot(np.log1p(data['High']), hist=False, color="b", kde_kws={"shade": True})
plt.xlabel("High")
plt.ylabel("Frequency")
plt.title("Distribution of High")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_24484\4097676012.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log1p(data['High']), hist=False, color="b", kde_kws={"shade": True})
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)

# %%
plt.figure(figsize=(15,5))
sns.distplot(np.log1p(data['Low']), hist=False, color="b", kde_kws={"shade": True})
plt.xlabel("Low")
plt.ylabel("Frequency")
plt.title("Distribution of Low")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_24484\1028783062.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log1p(data['Low']), hist=False, color="b", kde_kws={"shade": True})
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)

# %%
plt.figure(figsize=(15,5))
sns.distplot(np.log1p(data['Last']), hist=False, color="b", kde_kws={"shade": True})
plt.xlabel("Last")
plt.ylabel("Frequency")
plt.title("Distribution of Last")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_24484\3231134234.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log1p(data['Last']), hist=False, color="b", kde_kws={"shade": True})
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)

# %%
plt.figure(figsize=(15,5))
sns.distplot(np.log1p(data['Close']), hist=False, color="b", kde_kws={"shade": True})
plt.xlabel("Close")
plt.ylabel("Frequency")
plt.title("Distribution of Close")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_24484\2914676788.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log1p(data['Close']), hist=False, color="b", kde_kws={"shade": True})
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)

# %%
plt.figure(figsize=(15,5))
sns.distplot(np.log1p(data['Total Trade Quantity']), hist=False, color="b", kde_kws={"shade": True})
plt.xlabel("Total Trade Quantity")
plt.ylabel("Frequency")
plt.title("Distribution of Total Trade Quantity")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_24484\3617624649.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log1p(data['Total Trade Quantity']), hist=False, color="b", kde_kws={"shade": True})
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)

# %%
plt.figure(figsize=(15,5))
sns.distplot(np.log1p(data['Turnover (Lacs)']), hist=False, color="b", kde_kws={"shade": True})
plt.xlabel("Turnover (Lacs)")
plt.ylabel("Frequency")
plt.title("Distribution of Turnover (Lacs)")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_24484\450811341.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log1p(data['Turnover (Lacs)']), hist=False, color="b", kde_kws={"shade": True})
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)

# %%
#setting index as date
data['Date'] = pd.to_datetime(data.Date,format='%Y-%m-%d')
data.index = data['Date']

#plot
plt.figure(figsize=(16,8))
plt.plot(data['Total Trade Quantity'], label='Close Price history')

# %%
#setting index as date
data['Date'] = pd.to_datetime(data.Date,format='%Y-%m-%d')
data.index = data['Date']

#plot
plt.figure(figsize=(16,8))
plt.plot(data['Close'], label='Close Price history')

# %% [markdown]
# # LSTM

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[25], line 2
#       1 from sklearn.preprocessing import MinMaxScaler
# ----> 2 from keras.models import Sequential
#       3 from keras.layers import Dense, Dropout, LSTM
#
# ModuleNotFoundError: No module named 'keras'

# %%
data1 = data.sort_index(ascending=True, axis=0)
new_data = pd.DataFrame(index=range(0,len(data)),columns=['Date', 'Close'])
for i in range(0,len(data1)):
    new_data['Date'][i] = data1['Date'][i]
    new_data['Close'][i] = data1['Close'][i]
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_24484\929992424.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   new_data['Date'][i] = data1['Date'][i]
# C:\Users\HP\AppData\Local\Temp\ipykernel_24484\929992424.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# ...

# %%
#setting index
new_data.index = new_data.Date
new_data.drop('Date', axis=1, inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:7630: FutureWarning: Dtype inference on a pandas object (Series, Index, ExtensionArray) is deprecated. The Index constructor will keep the original dtype in the future. Call `infer_objects` on the result to get the old behavior.
#   return Index(index_like, name=name, copy=copy)

# %%
#split the train and test sets
dataset = new_data.values
train = dataset[0:987,:]
valid = dataset[987:,:]

# %%
train
# Out:
# array([[155.8],
#        [155.55],
#        [160.15],
#        [160.05],
#        [159.45],
#        [158.05],
#        [162.0],
#        [164.2],
#        [159.6],
#        [161.85],
#        [158.75],
#        [165.45],
#        [163.85],
#        [163.25],
#        [162.4],
#        [165.0],
#        [164.0],
#        [167.7],
#        [169.5],
#        [167.6],
#        [163.55],
#        [160.35],
#        [160.1],
#        [156.55],
#        [154.55],
#        [144.3],
#        [143.95],
#        [147.7],
#        [144.55],
#        [145.35],
#        [143.65],
#        [141.8],
#        [142.4],
#        [145.5],
#        [145.05],
#        [147.65],
#        [148.9],
#        [149.3],
#        [146.8],
#        [145.55],
#        [146.65],
#        [146.2],
#        [146.7],
#        [147.45],
#        [147.0],
#        [146.75],
#        [145.15],
#        [143.45],
#        [144.75],
#        [148.2],
#        [147.5],
#        [153.1],
#        [154.7],
#        [157.25],
# ...

# %%
valid
# Out:
# array([[208.3],
#        [208.45],
#        [209.4],
#        [212.0],
#        [210.25],
#        [209.6],
#        [210.3],
#        [206.8],
#        [204.6],
#        [203.1],
#        [209.65],
#        [205.3],
#        [209.8],
#        [220.5],
#        [226.8],
#        [226.95],
#        [227.8],
#        [226.35],
#        [225.3],
#        [234.7],
#        [225.0],
#        [224.5],
#        [240.45],
#        [236.15],
#        [234.4],
#        [246.7],
#        [250.9],
#        [251.95],
#        [259.9],
#        [274.9],
#        [273.15],
#        [274.05],
#        [274.8],
#        [278.7],
#        [277.45],
#        [287.75],
#        [280.2],
#        [287.1],
#        [283.55],
#        [279.05],
#        [279.95],
#        [274.95],
#        [284.0],
#        [288.45],
#        [298.35],
#        [287.8],
#        [284.45],
#        [284.3],
#        [286.85],
#        [290.85],
#        [300.65],
#        [300.85],
#        [300.15],
#        [302.75],
# ...

# %%
#converting dataset into x_train and y_train
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

# %%
x_train, y_train = [], []
for i in range(60,len(train)):
    x_train.append(scaled_data[i-60:i,0])
    y_train.append(scaled_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))
x_train
# Out:
# array([[[0.23823398],
#         [0.2371134 ],
#         [0.25773196],
#         ...,
#         [0.25907665],
#         [0.25930076],
#         [0.23442403]],
#
#        [[0.2371134 ],
#         [0.25773196],
#         [0.25728373],
#         ...,
#         [0.25930076],
#         [0.23442403],
#         [0.24069924]],
#
#        [[0.25773196],
#         [0.25728373],
#         [0.25459435],
#         ...,
#         [0.23442403],
#         [0.24069924],
#         [0.24271627]],
#
#        ...,
#
#        [[0.24697445],
#         [0.28641865],
#         [0.29964142],
#         ...,
#         [0.45047064],
#         [0.46234872],
#         [0.46526221]],
#
#        [[0.28641865],
#         [0.29964142],
#         [0.31869117],
#         ...,
#         [0.46234872],
#         [0.46526221],
#         [0.45853877]],
#
#        [[0.29964142],
#         [0.31869117],
#         [0.32608696],
#         ...,
#         [0.46526221],
#         [0.45853877],
#         [0.4787091 ]]])

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(LSTM(units=50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam',metrics=['accuracy'])
model.fit(x_train, y_train, epochs=15, batch_size=25, verbose=2)
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 # create and fit the LSTM network
# ----> 2 model = Sequential()
#       3 model.add(LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1],1)))
#       4 model.add(LSTM(units=50))
#
# NameError: name 'Sequential' is not defined

# %%
#predicting 246 values, using past 60 from the train data
inputs = new_data[len(new_data) - len(valid) - 60:].values
inputs = inputs.reshape(-1,1)
inputs  = scaler.transform(inputs)
inputs
# Out:
# array([[0.31869117],
#        [0.32608696],
#        [0.3207082 ],
#        [0.33325863],
#        [0.31869117],
#        [0.32496638],
#        [0.30770955],
#        [0.31174361],
#        [0.30188256],
#        [0.3070372 ],
#        [0.31174361],
#        [0.29471089],
#        [0.29807261],
#        [0.29986553],
#        [0.29067683],
#        [0.27991932],
#        [0.28686688],
#        [0.28597042],
#        [0.3038996 ],
#        [0.28395338],
#        [0.26647243],
#        [0.23913043],
#        [0.27588525],
#        [0.34110264],
#        [0.4087853 ],
#        [0.39421784],
#        [0.41125056],
#        [0.41909458],
#        [0.39085612],
#        [0.42088749],
#        [0.41057822],
#        [0.40632004],
#        [0.39309727],
#        [0.42312864],
#        [0.42738682],
#        [0.4255939 ],
#        [0.40632004],
#        [0.42155984],
#        [0.46302107],
#        [0.46212461],
#        [0.46727925],
#        [0.47781264],
#        [0.49036307],
# ...

# %%
X_test = []
for i in range(60,inputs.shape[0]):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)

X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
closing_price = model.predict(X_test)
closing_price = scaler.inverse_transform(closing_price)
closing_price
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 7
#       4 X_test = np.array(X_test)
#       6 X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
# ----> 7 closing_price = model.predict(X_test)
#       8 closing_price = scaler.inverse_transform(closing_price)
#       9 closing_price
#
# NameError: name 'model' is not defined

# %%
score, acc = model.evaluate(X_test,X_test, batch_size=25, verbose=2)
print('score', score)
print('accuracy', acc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 score, acc = model.evaluate(X_test,X_test, batch_size=25, verbose=2)
#       2 print('score', score)
#       3 print('accuracy', acc)
#
# NameError: name 'model' is not defined

# %%
#Root mean square Error
rms_value=np.sqrt(np.mean(np.power((valid-closing_price),2)))
rms_value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 #Root mean square Error
# ----> 2 rms_value=np.sqrt(np.mean(np.power((valid-closing_price),2)))
#       3 rms_value
#
# NameError: name 'closing_price' is not defined

# %%
train = new_data[:987]
valid = new_data[987:]
valid['Predictions'] = closing_price
plt.plot(train['Close'])
plt.plot(valid[['Close','Predictions']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 3
#       1 train = new_data[:987]
#       2 valid = new_data[987:]
# ----> 3 valid['Predictions'] = closing_price
#       4 plt.plot(train['Close'])
#       5 plt.plot(valid[['Close','Predictions']])
#
# NameError: name 'closing_price' is not defined

# %% [markdown]
# # Monte Carlo Simulation

# %%
import pandas_datareader.data as web
import pandas as pd
from datetime import datetime 
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 import pandas_datareader.data as web
#       2 import pandas as pd
#       3 from datetime import datetime
#
# ModuleNotFoundError: No module named 'pandas_datareader'

# %%
startdate = '2017-01-01'
today = datetime.today().strftime('%Y-%m-%d')
startdate, today
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 2
#       1 startdate = '2017-01-01'
# ----> 2 today = datetime.today().strftime('%Y-%m-%d')
#       3 startdate, today
#
# NameError: name 'datetime' is not defined

# %%
price = web.DataReader('AAPL', data_source = 'yahoo', start = startdate, end = today)['Adj Close']
price
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 price = web.DataReader('AAPL', data_source = 'yahoo', start = startdate, end = today)['Adj Close']
#       2 price
#
# NameError: name 'web' is not defined

# %%
# daily return and volatiltiy
daily_return = price.pct_change()
daily_vol = daily_return.std()
daily_return, daily_vol
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 # daily return and volatiltiy
# ----> 2 daily_return = price.pct_change()
#       3 daily_vol = daily_return.std()
#       4 daily_return, daily_vol
#
# NameError: name 'price' is not defined

# %%
last_price = price[-1]
last_price
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 last_price = price[-1]
#       2 last_price
#
# NameError: name 'price' is not defined

# %%
# Monte Carlo Simulation setup
num_simulation = 5
num_days = 252
simulation_df = pd.DataFrame()

# %%
for x in range(num_simulation):
    count = 0
    daily_vol = daily_return.std()
    
    price_series = []
    
    prices = last_price*(1 + np.random.normal(0, daily_vol))
    price_series.append(prices)
    
    for y in range(num_days):
        if count == 251:
            break
        prices = price_series[count]*(1+np.random.normal(0, daily_vol))
        price_series.append(prices)
        count += 1
    
    simulation_df[x] = price_series
simulation_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 3
#       1 for x in range(num_simulation):
#       2     count = 0
# ----> 3     daily_vol = daily_return.std()
#       5     price_series = []
#       7     prices = last_price*(1 + np.random.normal(0, daily_vol))
#
# NameError: name 'daily_return' is not defined

# %%
fig = plt.figure()
fig.suptitle('Monte Carlo Simulation')
plt.plot(simulation_df, lw = 1)
plt.axhline(y = last_price, color = 'r', linestyle = '-')
plt.xlabel('Day')
plt.ylabel('Price')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 4
#       2 fig.suptitle('Monte Carlo Simulation')
#       3 plt.plot(simulation_df, lw = 1)
# ----> 4 plt.axhline(y = last_price, color = 'r', linestyle = '-')
#       5 plt.xlabel('Day')
#       6 plt.ylabel('Price')
#
# NameError: name 'last_price' is not defined

# %%
#GUI

# %%
from tkinter import * 
from matplotlib.figure import Figure
from matplotlib.backends.backend_tkagg import (FigureCanvasTkAgg, 
NavigationToolbar2Tk)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# plot function is created for 
# plotting the graph in 
# tkinter window
def plot():
  
    # the figure that will contain the plot
    fig = Figure(figsize = (5, 5),
                 dpi = 100)
  
    # list of squares
    y = model.predict(closing_price)
    
    # adding the subplot
    plot1 = fig.add_subplot(111)
  

    plot1.set_xlabel('value')
    plot1.set_ylabel('base')
    
    #plot1.inverse.transform(y)
    # plotting the graph
    # plot1.xlabels("")
    # plot1.ylabels("")
    plot1.plot(y)

    #fig.xlabel("")
    #fig.ylabel("")
    #print(scaler.transform(y))
    
  

    # creating the Tkinter canvas
    # containing the Matplotlib figure
    canvas = FigureCanvasTkAgg(fig,
                               master = window)  
    canvas.draw()
  
    # placing the canvas on the Tkinter window
    canvas.get_tk_widget().pack()
  
    # creating the Matplotlib toolbar
    toolbar = NavigationToolbar2Tk(canvas,
                                   window)
    toolbar.update()
  
    # placing the toolbar on the Tkinter window
    canvas.get_tk_widget().pack()
  
# the main Tkinter window
window = Tk()
  
# setting the title 
window.title('Prediction of Stock Market')
  
# dimensions of the main window
window.geometry("500x500")
  
# button that displays the plot
plot_button = Button(master = window, 
                     command = plot,
                     height = 2, 
                     width = 10,
                     text = "Predict")
  
# place the button 
# in main window
plot_button.pack()
  
# run the gui
window.mainloop()
